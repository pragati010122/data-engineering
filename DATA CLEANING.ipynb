# %%
import snowflake.connector
import pandas as pd

print('opening..')

cnn = snowflake.connector.connect(
     user='SAIPRIYA',
     password='Priya@123',
     account='kw25469.ap-south-1.aws',
     warehouse='project_warehouse',
     database='project_database',
     schema='project_schema'
     )
#cursor

cs = cnn.cursor()
sql = 'SELECT TABLE_NAME,COLUMN_NAME, DATA_TYPE FROM INFORMATION_SCHEMA.COLUMNS WHERE TABLE_NAME = "PROJECT_TABLE1";'
cs.execute(sql)
cs.close()
cnn.close()

print(df.head(10))
# Out:
# opening..
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# C:\Users\SAIMAN~1\AppData\Local\Temp/ipykernel_21452/50866414.py in <module>
#      16 cs = cnn.cursor()
#      17 sql = 'SELECT TABLE_NAME,COLUMN_NAME, DATA_TYPE FROM INFORMATION_SCHEMA.COLUMNS WHERE TABLE_NAME = "PROJECT_TABLE1";'
# ---> 18 cs.execute(sql)
#      19 cs.close()
#      20 cnn.close()
#
# ~\anaconda3\lib\site-packages\snowflake\connector\cursor.py in execute(self, command, params, _bind_stage, timeout, _exec_async, _do_reset, _put_callback, _put_azure_callback, _put_callback_output_stream, _get_callback, _get_azure_callback, _get_callback_output_stream, _show_progress_bar, _statement_params, _is_internal, _describe_only, _no_results, _use_ijson, _is_put_get, _raise_put_get_error, _force_put_overwrite, file_stream)
#     796                 "sfqid": self._sfqid,
#     797             }
# ...

# %%
import snowflake.connector
import pandas as pd

print('opening..')

cnn = snowflake.connector.connect(
     user='SAIPRIYA',
     password='Priya@123',
     account='kw25469.ap-south-1.aws',
     warehouse='project_warehouse',
     database='project_database',
     schema='project_schema'
    )
#cursor

cs = cnn.cursor()
sql = 'SELECT TABLE_NAME,COLUMN_NAME, DATA_TYPE FROM INFORMATION_SCHEMA.COLUMNS WHERE TABLE_NAME = "PROJECT_TABLE2";'
cs.execute(sql)
df = cs.fetch_pandas_all()
cs.close()
cnn.close()

print(df.head(10))
# Out:
# opening..
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# C:\Users\SAIMAN~1\AppData\Local\Temp/ipykernel_21452/259645211.py in <module>
#      16 cs = cnn.cursor()
#      17 sql = 'SELECT TABLE_NAME,COLUMN_NAME, DATA_TYPE FROM INFORMATION_SCHEMA.COLUMNS WHERE TABLE_NAME = "PROJECT_TABLE2";'
# ---> 18 cs.execute(sql)
#      19 df = cs.fetch_pandas_all()
#      20 cs.close()
#
# ~\anaconda3\lib\site-packages\snowflake\connector\cursor.py in execute(self, command, params, _bind_stage, timeout, _exec_async, _do_reset, _put_callback, _put_azure_callback, _put_callback_output_stream, _get_callback, _get_azure_callback, _get_callback_output_stream, _show_progress_bar, _statement_params, _is_internal, _describe_only, _no_results, _use_ijson, _is_put_get, _raise_put_get_error, _force_put_overwrite, file_stream)
#     796                 "sfqid": self._sfqid,
#     797             }
# ...

# %%
import snowflake.connector
import pandas as pd

print('opening..')

cnn = snowflake.connector.connect(
     user='SAIPRIYA',
     password='Priya@123',
     account='kw25469.ap-south-1.aws',
     warehouse='project_warehouse',
     database='project_database',
     schema='project_schema'
    )
#cursor

cs = cnn.cursor()
sql = 'alter table "PROJECT_TABLE1" alter column "TIME"  timestamp_ntz,"generation biomass" number,"generation marine"  number,"generation fossile brown coal/lignite" number,"generation fossile coal derived gas" number,"generation fossile gas" number,"generation fossile hard coal" number,"generation fossile oil" number,"generation fossile oil shale" number,"generation fossile peat" number,"generation fossile geothermal" number,"generation hydro pumped storage aggregated" number,"generation hydro pumped storage consumption" number,"generation hydro run-of-river and poundage" number,"generation hydro water reservoir" number,"generation marine" number,"generation nuclear" number,"generation other" number,"generation other renewable" number,"generation solar" number,"generation waste" number,"generation wind offshore" number,"generation wind onshore" number,"forecast solar day ahead" number,"forecast wind offshore eday ahead" number,"forecast wind onshore day ahead" number,"total load forecast" number,"total load actual" number,"price day ahead" float,"price actual" float;'
cs.execute(sql)
cs.close()
cnn.close()

print(df.head(10))
# Out:
# opening..
#                  TIME  generation biomass  \
# 0 2015-01-01 05:00:00               410.0
# 1 2015-01-01 05:00:00               410.0
# 2 2015-01-01 05:00:00               410.0
# 3 2015-01-01 05:00:00               410.0
# 4 2015-01-01 05:00:00               410.0
# 5 2015-01-01 06:00:00               401.0
# 6 2015-01-01 06:00:00               401.0
# 7 2015-01-01 06:00:00               401.0
# 8 2015-01-01 06:00:00               401.0
# 9 2015-01-01 06:00:00               401.0
#
#    generation fossile brown coal/lignite  generation fossile coal derived gas  \
# 0                                  178.0                                  0.0
# 1                                  178.0                                  0.0
# 2                                  178.0                                  0.0
# 3                                  178.0                                  0.0
# 4                                  178.0                                  0.0
# ...

# %%
import snowflake.connector
import pandas as pd

print('opening..')

cnn = snowflake.connector.connect(
     user='SAIPRIYA',
     password='Priya@123',
     account='kw25469.ap-south-1.aws',
     warehouse='project_warehouse',
     database='project_database',
     schema='project_schema'
    )
#cursor

cs = cnn.cursor()
sql = 'alter table "PROJECT_TABLE2" alter column "DT_ISO" timestamp_ntz,"CITY_NAME" text,"TEMP" float,"TEMP_MIN" float,"TEMP_MAX" float,"PRESSURE" number,"HUMIDITY" number,"WIND_SPEED" number,"WIND_DEG" number,"RAIN_1H" number,"RAIN_3H" number,"SNOW_3H" number,"CLOUDS_ALL" number,"WEATHER_ID" number,"WEATHER_MAIN" text,"WEATHER_DESCRIPTION" text,"WEATHER_ICON" text;'
cs.execute(sql)
cs.close()
cnn.close()

print(df.head(10))
# Out:
# opening..
#                  TIME  generation biomass  \
# 0 2015-01-01 05:00:00               410.0
# 1 2015-01-01 05:00:00               410.0
# 2 2015-01-01 05:00:00               410.0
# 3 2015-01-01 05:00:00               410.0
# 4 2015-01-01 05:00:00               410.0
# 5 2015-01-01 06:00:00               401.0
# 6 2015-01-01 06:00:00               401.0
# 7 2015-01-01 06:00:00               401.0
# 8 2015-01-01 06:00:00               401.0
# 9 2015-01-01 06:00:00               401.0
#
#    generation fossile brown coal/lignite  generation fossile coal derived gas  \
# 0                                  178.0                                  0.0
# 1                                  178.0                                  0.0
# 2                                  178.0                                  0.0
# 3                                  178.0                                  0.0
# 4                                  178.0                                  0.0
# ...

# %%
import snowflake.connector
import pandas as pd

print('opening..')

cnn = snowflake.connector.connect(
     user='SAIPRIYA',
     password='Priya@123',
     account='kw25469.ap-south-1.aws',
     warehouse='project_warehouse',
     database='project_database',
     schema='project_schema'
    )
#cursor

cs = cnn.cursor()
sql = 'select TIME,coalesce("generation biomass",(select avg("generation biomass") from "PROJECT_TABLE1")) as "generation biomass",coalesce("generation fossile brown coal/lignite",(select avg("generation fossile brown coal/lignite") from "PROJECT_TABLE1")) as "generation fossile brown coal/lignite",coalesce("generation fossile coal derived gas",(select avg("generation fossile coal derived gas") from "PROJECT_TABLE1")) as "generation fossile coal derived gas",coalesce("generation fossile gas",(select avg("generation fossile gas") from "PROJECT_TABLE1")) as "generation fossile gas",coalesce("generation fossile hard coal",(select avg("generation fossile hard coal") from "PROJECT_TABLE1")) as "generation fossile hard coal",coalesce("generation fossile oil",(select avg("generation fossile oil") from "PROJECT_TABLE1")) as "generation fossile oil",coalesce("generation fossile oil shale",(select avg("generation fossile oil shale") from "PROJECT_TABLE1")) as "generation fossile oil shale",coalesce("generation fossile peat",(select avg("generation fossile peat") from "PROJECT_TABLE1")) as "generation fossile peat",coalesce("generation fossile geothermal",(select avg("generation fossile geothermal") from "PROJECT_TABLE1")) as "generation fossile geothermal",coalesce("generation hydro pumped storage aggregated",(select avg("generation hydro pumped storage aggregated") from "PROJECT_TABLE1")) as "generation hydro pumped storage aggregated",coalesce("generation hydro pumped storage consumption",(select avg("generation hydro pumped storage consumption") from "PROJECT_TABLE1")) as "generation hydro pumped storage consumption",coalesce("generation hydro run-of-river and poundage",(select avg("generation hydro run-of-river and poundage") from "PROJECT_TABLE1")) as "generation hydro run-of-river and poundage",coalesce("generation hydro water reservoir",(select avg("generation hydro water reservoir") from "PROJECT_TABLE1")) as "generation hydro water reservoir",coalesce("generation marine",(select avg("generation marine") from "PROJECT_TABLE1")) as "generation marine",coalesce("generation nuclear",(select avg("generation nuclear") from "PROJECT_TABLE1")) as "generation nuclear",coalesce("generation other",(select avg("generation other") from "PROJECT_TABLE1")) as "generation other",coalesce("generation other renewable",(select avg("generation other renewable") from "PROJECT_TABLE1")) as "generation other renewable",coalesce("generation solar",(select avg("generation solar") from "PROJECT_TABLE1")) as "generation solar",coalesce("generation waste",(select avg("generation waste") from "PROJECT_TABLE1")) as "generation waste",coalesce("generation wind offshore",(select avg("generation wind offshore") from "PROJECT_TABLE1")) as "generation wind offshore",coalesce("generation wind onshore",(select avg("generation wind onshore") from "PROJECT_TABLE1")) as "generation windonshore",coalesce("forecast solar day ahead",(select avg("forecast solar day ahead") from "PROJECT_TABLE1")) as "forecast solar day ahead",coalesce("forecast wind offshore eday ahead",(select avg("forecast wind offshore eday ahead") from "PROJECT_TABLE1")) as "forecast wind offshore eday ahead",coalesce("forecast wind onshore day ahead",(select avg("forecast wind onshore day ahead") from "PROJECT_TABLE1")) as "forecast wind onshore day ahead",coalesce("forecast solar day ahead",(select avg("forecast solar day ahead") from "PROJECT_TABLE1")) as "forecast solar day ahead",coalesce("forecast solar day ahead",(select avg("forecast solar day ahead") from "PROJECT_TABLE1")) as "forecast solar day ahead",coalesce("total load forecast",(select avg("total load forecast") from "PROJECT_TABLE1")) as "total load forecast",coalesce("total load actual",(select avg("total load actual") from "PROJECT_TABLE1")) as "total load actual",coalesce("price day ahead",(select avg("price day ahead") from "PROJECT_TABLE1")) as "price day ahead",coalesce("price actual",(select avg("price actual") from "PROJECT_TABLE1")) as "price actual" from "PROJECT_TABLE1";'
cs.execute(sql)
cs.close()
cnn.close()

print(df.head(10))
# Out:
# opening..
#                  TIME  generation biomass  \
# 0 2015-01-01 05:00:00               410.0
# 1 2015-01-01 05:00:00               410.0
# 2 2015-01-01 05:00:00               410.0
# 3 2015-01-01 05:00:00               410.0
# 4 2015-01-01 05:00:00               410.0
# 5 2015-01-01 06:00:00               401.0
# 6 2015-01-01 06:00:00               401.0
# 7 2015-01-01 06:00:00               401.0
# 8 2015-01-01 06:00:00               401.0
# 9 2015-01-01 06:00:00               401.0
#
#    generation fossile brown coal/lignite  generation fossile coal derived gas  \
# 0                                  178.0                                  0.0
# 1                                  178.0                                  0.0
# 2                                  178.0                                  0.0
# 3                                  178.0                                  0.0
# 4                                  178.0                                  0.0
# ...

# %%
import snowflake.connector
import pandas as pd

print('opening..')

cnn = snowflake.connector.connect(
     user='SAIPRIYA',
     password='Priya@123',
     account='kw25469.ap-south-1.aws',
     warehouse='project_warehouse',
     database='project_database',
     schema='project_schema'
    )
#cursor

cs = cnn.cursor()
sql = 'select DT_ISO,coalesce("CITY_NAME",(select mode("CITY_NAME") from "PROJECT_TABLE2")) as "CITY_NAME",coalesce("TEMP",(select avg("TEMP") from "PROJECT_TABLE2")) as "TEMP",coalesce("TEMP_MIN",(select avg("TEMP_MIN") from "PROJECT_TABLE2")) as "TEMP_MIN",coalesce("TEMP_MAX",(select avg("TEMP_MAX") from "PROJECT_TABLE2")) as "TEMPMAX",coalesce("PRESSURE",(select avg("PRESSURE") from "PROJECT_TABLE2")) as "PRESSURE",coalesce("HUMIDITY",(select avg("HUMIDITY") from "PROJECT_TABLE2")) as "HUMIDITY",coalesce("WIND_SPEED",(select avg("WIND_SPEED") from "PROJECT_TABLE2")) as "WIND_SPEED",coalesce("WIND_DEG",(select avg("WIND_DEG") from "PROJECT_TABLE2")) as "WIND_DEG",coalesce("RAIN_1H",(select avg("RAIN_1H") from "PROJECT_TABLE2")) as "RAIN_1H",coalesce("RAIN_3H",(select avg("RAIN_3H") from "PROJECT_TABLE2")) as "RAIN_3H",coalesce("SNOW_3H",(select avg("SNOW_3H") from "PROJECT_TABLE2")) as "SNOW_3H",coalesce("CLOUDS_ALL",(select avg("CLOUDS_ALL") from "PROJECT_TABLE2")) as "CLOUDS_ALL",coalesce("WEATHER_ID",(select mode("WEATHER_ID") from "PROJECT_TABLE2")) as "WEATHER_ID",coalesce("WEATHER_MAIN",(select mode("WEATHER_MAIN") from "PROJECT_TABLE2")) as "WEATHER_MAIN",coalesce("WEATHER_DESCRIPTION",(select mode("WEATHER_DESCRIPTION") from "PROJECT_TABLE2")) as "WEATHER_DESCRIPTION",coalesce("WEATHER_ICON",(select mode("WEATHER_ICON") from "PROJECT_TABLE2")) as "WEATHER_ICON"from  "PROJECT_TABLE2";'
cs.execute(sql)
cs.close()
cnn.close()

print(df.head(10))
# Out:
# opening..
#                  TIME  generation biomass  \
# 0 2015-01-01 05:00:00               410.0
# 1 2015-01-01 05:00:00               410.0
# 2 2015-01-01 05:00:00               410.0
# 3 2015-01-01 05:00:00               410.0
# 4 2015-01-01 05:00:00               410.0
# 5 2015-01-01 06:00:00               401.0
# 6 2015-01-01 06:00:00               401.0
# 7 2015-01-01 06:00:00               401.0
# 8 2015-01-01 06:00:00               401.0
# 9 2015-01-01 06:00:00               401.0
#
#    generation fossile brown coal/lignite  generation fossile coal derived gas  \
# 0                                  178.0                                  0.0
# 1                                  178.0                                  0.0
# 2                                  178.0                                  0.0
# 3                                  178.0                                  0.0
# 4                                  178.0                                  0.0
# ...
